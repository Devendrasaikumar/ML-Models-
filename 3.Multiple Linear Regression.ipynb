# %% [markdown]
# # <font color='Blue'>Multiple Linear Regression .</font>

# %% [markdown]
# - it's check the relationship between one dependent variable (Y) and Two are more independent variables (X).

# %% [markdown]
# - It's also predict the value of a dependent variable (Y) based on one independent variables (X).

# %% [markdown]
# **Mathematical Equation**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Where as :-
#
# - **Y** :- is the dependent variable (target variable).
# - **X1, X2, …, Xn** :-  are the independent variables (feature variables).
# - **β0** :- is the intercept
# - **β1, β2, …, βn** :- are the coefficients of the independent variables
# - **ε** :- is the error term (residual)

# %% [markdown]
# # <font color='Blue'>   </font>

# %% [markdown]
# #### <font color='magenta'> Things we have to know first  </font>

# %% [markdown]
# - **Coefficients**
# - **Predicting**
# - **Residuals**
# - **Residuals Standard Error**
# - **P-Value**

# %% [markdown]
# # <font color='Blue'>    </font>

# %% [markdown]
# ### <font color='Green'>Coefficients  </font>

# %% [markdown]
# To find Coefficients of β1, β2, …, βn we have some complex steps to do that.

# %% [markdown]
# **Mathematical equation**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Where as :-
#
# - **Xᵀ** :- is the transpose of 𝑋.
#
# - **(Xᵀ X)⁻¹** :-  is the inverse of the matrix (Xᵀ X)

# %% [markdown]
# **Example**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <font color='Blue'>  </font>

# %% [markdown]
# ###  <font color='Green'> 2. Predict .</font>

# %% [markdown]
# We can predict the value of a dependent variable (Y) based on one independent variables (X).

# %% [markdown]
# **Mathmatical equation to find the predicted values**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Where as :-
#
# - **Ŷ** is the predicted value of the dependent variable
# - **β0** is the intercept or constant term
# - **β1, β2, …, βn** are the coefficients of the independent variables
# - **X1, X2, …, Xn** are the values of the independent variables

# %% [markdown]
# # <font color='Blue'> </font>

# %% [markdown]
# ### <font color='Green'>3. Residuals  </font>

# %% [markdown]
#  It tells the difference between Actual value and Predicted value.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Where as :-
#
# - **ei** :- Reisdual
# - **Yi** :- Dependent Data
# - **Y^i** :- Predicted data

# %% [markdown]
# ##### <font color='Brown'>  </font>

# %% [markdown]
# ### <font color='Green'>4.Residuals Standard Error</font>

# %% [markdown]
# Simpmly, We called it as Standard Deviation for the Residuals

# %% [markdown]
# **Mathmatical formula to find Residual Standard Error**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **n** :- No.Of Data Points

# %% [markdown]
# ##### <font color='Brown'>  </font>

# %% [markdown]
# ### <font color='Green'>5.P - Value </font>

# %% [markdown]
# - It helps you decide whether to reject null hypothesis and conclude that there is a Signifincent relationship between Variable in Regression

# %% [markdown]
# - It is a statastical test.

# %% [markdown]
# **Mathematical function to find the P-Value**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Where as :-
#
# - **β^1** :- Estimated slope of the regression line.
# - **SE(β^1)** :- Standard error of the estimated slope.

# %% [markdown]
# # <font color='Blue'>   </font>

# %% [markdown]
# ### <font color='magenta'>Assumptions   </font>

# %% [markdown]
# **Same assumptions what we did in Simple Linear Regression notebook file**

# %% [markdown]
# # <font color='Blue'>  </font>

# %% [markdown]
# # <font color='Blue'>  </font>

# %% [markdown]
# # <font color='red'>Multiple Linear Regression Model Buliding.</font>

# %% [markdown]
# **Task is to perform a multiple linear regression analysis to predict the price of Toyota corolla based on the given attributes.**

# %% [markdown]
# Loading Data set and buliding model

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("D:/Sai/Data sets/MLR/ToyotaCorolla - MLR.xlsx")
df
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Weight  Price
# 0            23  46986   90  2000      3      5    1165  13500
# 1            23  72937   90  2000      3      5    1165  13750
# 2            24  41711   90  2000      3      5    1165  13950
# 3            26  48000   90  2000      3      5    1165  14950
# 4            30  38500   90  2000      3      5    1170  13750
# ...         ...    ...  ...   ...    ...    ...     ...    ...
# 1431         69  20544   86  1300      3      5    1025   7500
# 1432         72  19000   86  1300      3      5    1015  10845
# 1433         71  17016   86  1300      3      5    1015   8500
# 1434         70  16916   86  1300      3      5    1015   7250
# 1435         76      1  110  1600      5      5    1114   6950
#
# [1436 rows x 8 columns]

# %% [markdown]
# - **Note** :- **Price** is only Dependent Variable.
# - Remaining all variables are Indenpendent Variable.

# %%
df.head()
# Out:
#    Age_08_04     KM  HP    cc  Doors  Gears  Weight  Price
# 0         23  46986  90  2000      3      5    1165  13500
# 1         23  72937  90  2000      3      5    1165  13750
# 2         24  41711  90  2000      3      5    1165  13950
# 3         26  48000  90  2000      3      5    1165  14950
# 4         30  38500  90  2000      3      5    1170  13750

# %%
df.tail()
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Weight  Price
# 1431         69  20544   86  1300      3      5    1025   7500
# 1432         72  19000   86  1300      3      5    1015  10845
# 1433         71  17016   86  1300      3      5    1015   8500
# 1434         70  16916   86  1300      3      5    1015   7250
# 1435         76      1  110  1600      5      5    1114   6950

# %%
df.mean()
# Out:
# Age_08_04       55.947075
# KM           68533.259749
# HP             101.502089
# cc            1576.855850
# Doors            4.033426
# Gears            5.026462
# Weight        1072.459610
# Price        10730.824513
# dtype: float64

# %%
df.shape
# Out:
# (1436, 8)

# %%
df.columns
# Out:
# Index(['Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Weight', 'Price'], dtype='object')

# %%
df.dtypes
# Out:
# Age_08_04    int64
# KM           int64
# HP           int64
# cc           int64
# Doors        int64
# Gears        int64
# Weight       int64
# Price        int64
# dtype: object

# %%
df.corr()
# Out:
#            Age_08_04        KM        HP        cc     Doors     Gears  \
# Age_08_04   1.000000  0.505672 -0.156622 -0.098084 -0.148359 -0.005364
# KM          0.505672  1.000000 -0.333538  0.102683 -0.036197  0.015023
# HP         -0.156622 -0.333538  1.000000  0.035856  0.092424  0.209477
# cc         -0.098084  0.102683  0.035856  1.000000  0.079903  0.014629
# Doors      -0.148359 -0.036197  0.092424  0.079903  1.000000 -0.160141
# Gears      -0.005364  0.015023  0.209477  0.014629 -0.160141  1.000000
# Weight     -0.470253 -0.028598  0.089614  0.335637  0.302618  0.020613
# Price      -0.876590 -0.569960  0.314990  0.126389  0.185326  0.063104
#
#              Weight     Price
# Age_08_04 -0.470253 -0.876590
# KM        -0.028598 -0.569960
# HP         0.089614  0.314990
# cc         0.335637  0.126389
# Doors      0.302618  0.185326
# Gears      0.020613  0.063104
# Weight     1.000000  0.581198
# Price      0.581198  1.000000

# %%
X= df.iloc[:,0:7]
Y=df["Price"]
print(X.head())
print(Y.head())
# Out:
#    Age_08_04     KM  HP    cc  Doors  Gears  Weight
# 0         23  46986  90  2000      3      5    1165
# 1         23  72937  90  2000      3      5    1165
# 2         24  41711  90  2000      3      5    1165
# 3         26  48000  90  2000      3      5    1165
# 4         30  38500  90  2000      3      5    1170
# 0    13500
# 1    13750
# 2    13950
# 3    14950
# 4    13750
# Name: Price, dtype: int64

# %%
import matplotlib.pyplot as plt
for i in X:
    plt.scatter(x=X[i],y=Y,color='g')
    print(i,plt.show())
    plt.boxplot(X[i])
    plt.show()
    plt.hist(X[i])
    plt.show()
    print("___________________________________________________________________________________________")
# Out:
# Age_08_04 None
# ___________________________________________________________________________________________
# KM None
# ___________________________________________________________________________________________
# HP None
# ___________________________________________________________________________________________
# cc None
# ___________________________________________________________________________________________
# Doors None
# ___________________________________________________________________________________________
# Gears None
# ___________________________________________________________________________________________
# Weight None
# ___________________________________________________________________________________________

# %%
import seaborn as sns
sns.set_style(style='darkgrid')
sns.pairplot(df)

# %%
# Separate features and target variable
X = df[['Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Weight']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression 
Lr=LinearRegression()
Lr.fit(X,y)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = Lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Compute performance metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 1916641.0586119683
# R² Score: 0.8623314453889765

# %%
# Define a new data point (example)
new_data = pd.DataFrame({ 'Age_08_04': [70], 
                         'KM': [16916], 
                         'HP': [86], 
                         'cc': [1300], 
                         'Doors': [3], 
                         'Gears': [5], 
                         'Weight': [1015]})

# Predict the price using the model
predicted_price = Lr.predict(new_data)

# Print the predicted price
print("Predicted Price:", predicted_price[0])
# Out:
# Predicted Price: 8532.693138940276

# %% [markdown]
# ### <font color='red'>    </font>

# %% [markdown]
# ### <font color='red'>     </font>

# %% [markdown]
# ### <font color='magenta'> Deployement part   </font>

# %%
# Save the model

import joblib
joblib.dump(Lr, 'Toyota_corolla_Predication.pkl')
# Out:
# ['Toyota_corolla_Predication.pkl']

# %%
import streamlit as st
import joblib
import numpy as np
import pandas as pd

# Load the dataset
df = pd.read_excel("D:/Sai/Data sets/MLR/ToyotaCorolla - MLR.xlsx")

# Load your trained model
model = joblib.load('Toyota_corolla_Predication.pkl')

# Title of the app
st.title("Toyota Corolla Car Price Prediction")

# Input fields for the model
age = st.number_input("Age (years)", min_value=0, max_value=50, value=0)
km = st.number_input("Kilometers Driven (KM)", min_value=0, value=0)
hp = st.number_input("Horsepower (HP)", min_value=0, value=0)
cc = st.number_input("Cubic Centimeters (cc)", min_value=0, value=0)
doors = st.selectbox("Number of Doors", [2, 3, 4, 5])
gears = st.selectbox("Number of Gears", [5, 6])
weight = st.number_input("Weight (kg)", min_value=800, max_value=3000, value=800)

# Prepare input data for prediction
input_features = np.array([[age, km, hp, cc, doors, gears, weight]])

# Prediction button
if st.button("Predict Price"):
    prediction = model.predict(input_features)
    st.write(f"The predicted price of the Toyota Corolla is: ${prediction[0]:,.2f}")

# %% [markdown]
# # <font color='Blue'>   </font>

# %% [markdown]
# # <font color='Blue'>   </font>

# %% [markdown]
# ### <font color='red'> Another Method   </font>

# %% [markdown]
# - statastical Ols method
#
# **When we Use this one and Explination of this**
#
# - For theoretical understanding and detailed statistical analysis, OLS might be preferred.
# - Using This means you can compute the coefficients directly using matrix operations, which can be computationally efficient for small to moderate-sized datasets.

# %%
import statsmodels.api as sm
# Define the dependent variable (target) and independent variables (features)
X = df[['Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Weight']]
y = df['Price']

# Add a constant to the independent variables
X = sm.add_constant(X)

# Create a multiple linear regression model
model = sm.OLS(y, X).fit()
print(model.summary())

# Define a new data point (example)
new_data = pd.DataFrame({'const': [1], 
                         'Age_08_04': [25], 
                         'KM': [50000], 
                         'HP': [100], 
                         'cc': [1800], 
                         'Doors': [3], 
                         'Gears': [5], 
                         'Weight': [1150]})

# Predict the price using the model
predicted_price = model.predict(new_data)

# Print the predicted price
print("Predicted Price:", predicted_price[0])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1284.
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):               0.00
# Time:                        16:36:24   Log-Likelihood:                -12380.
# No. Observations:                1436   AIC:                         2.478e+04
# Df Residuals:                    1428   BIC:                         2.482e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7116.7137   1318.946     -5.396      0.000   -9703.993   -4529.435
# ...

# %% [markdown]
# #  <font color='red'> END.   </font>
